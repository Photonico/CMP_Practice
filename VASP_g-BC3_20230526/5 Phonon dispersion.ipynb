# %% [markdown]
# # Phonon Dispersion for g-BC3
#
# Electronic density versus energy
#
# ## Phonon dispersion versus energy

# %%
#### Declarations of process functions for Phonon dispersion

import xml.etree.ElementTree as ET

def extract_phonon_dispersion_data(file_path):
