# %% [markdown]
# # Phonon DOS Plotting for g-BC3
#
# Phonon electronic density versus energy
#
# ## Phonon electronic density versus energy
