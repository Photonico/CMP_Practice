# %% [markdown]
# # Phonon DOS Plotting for g-BC3
#
# Phonon electronic density versus energy
#
# ## Phonon electronic density versus energy

# %%
#### Declarations of process functions for Phonon DOS

import xml.etree.ElementTree as ET

## Extract Phonon DOS from vasprun.xml
def extract_phonon_dos_data(file_path):
# Out:
# []
