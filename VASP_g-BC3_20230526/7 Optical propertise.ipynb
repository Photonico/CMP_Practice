# %% [markdown]
# # Optical Propertise for g-BC3
#
# Optical propertise versus energy
#
# ## Optical propertise versus energy

# %%
#### Declarations of process functions for Optical Propertise

import xml.etree.ElementTree as ET

def extract_optical_data(file_path):
